# %%
from IPython.display import Image

# %%
#假設檢定的種類
# 1. 根據H1 所定訂範圍分類
    #右尾檢定
    #左尾檢定
    #雙尾檢定



# 2. 根據樣本的範圍
    #單樣本檢定
    #雙樣本檢定: 比較兩種群體（非相依）
    #成對樣本: 比較兩種群體（相依）


# 3. 根據檢定目的
    #平均數檢定
    #比例檢定: 機率

# %%
# 統計上重要的抽樣分配
    # t 分配
    # 卡方分配
    # F 分配
Image(url='http://cumatrixfile.cupoy.com/00000176E15834E90000001E6375706F795F72656C656173654349/marathon/1610076223345')
# Out:
# <img src="http://cumatrixfile.cupoy.com/00000176E15834E90000001E6375706F795F72656C656173654349/marathon/1610076223345"/>

# %%
# 假設檢定的誤差類型
Image(url='https://pic.pimg.tw/yourgene/1484708489-54953476.png')
# Out:
# <img src="https://pic.pimg.tw/yourgene/1484708489-54953476.png"/>

# %%
Image(url='http://cumatrixfile.cupoy.com/00000176E15834E90000001E6375706F795F72656C656173654349/marathon/1610076223347')
# Out:
# <img src="http://cumatrixfile.cupoy.com/00000176E15834E90000001E6375706F795F72656C656173654349/marathon/1610076223347"/>

# %% [markdown]
# ![no_effect.jpeg](attachment:no_effect.jpeg)

# %% [markdown]
# ![large.jpeg](attachment:large.jpeg)

# %%
#在課堂中，檢定 H0：μ ≦ 0，H1：μ > 0，假設在 H0 為真下，分配為 N(0,1)，H1為真下，分配為N(2.1)。
#如果拒絕域改變時，α 和 β 會怎樣變化。

Image(url='http://cumatrixfile.cupoy.com/00000176E15834E90000001E6375706F795F72656C656173654349/marathon/1610076223351')
# Out:
# <img src="http://cumatrixfile.cupoy.com/00000176E15834E90000001E6375706F795F72656C656173654349/marathon/1610076223351"/>

# %%
#1.   假設 x̄ > 2，拒絕 H0，α 會變大／變小？β 會變大／變小？
# α 會變小, β 會變大

# %%
#2.   假設 x̄ > 0.2，拒絕 Ho，會變大／變小？β 會變大/變小？
# α 會變大, β 會變小

# %%
#3.   α 和 β 有關聯性？
# 權衡關係，一邊變大，另一邊變小
