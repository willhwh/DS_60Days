# %%
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
#Matplotlib (靜態的套件)：基礎 2D 及 3D 可視化
#Seaborn：基礎 2D 及 3D 可視化
#Bokeh：交互資訊可視化
#Basemap：地圖可視化

# %% [markdown]
# # HW

# %%
#畫出 cos 圖檔，並儲存
#畫出完整的 cos 圖形
x = np.arange(0,180)
y = np.cos(x)

plt.plot(x, y)

plt.show()

# 如果要存成圖形檔:
# 把 pyplot.show() 換成下面這行:plt.savefig("filename.png",dpi=300,format="png")

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

'''
#作業

#方法不只有一種

'''
color = np.arctan2(Y,X)
plt.scatter(X,Y,c=color,alpha=0.5) #alpha 透明度 #c colorplate


plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.show()
