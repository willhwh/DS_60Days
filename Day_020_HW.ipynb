# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
data
# Out:
# array([[ 0.39593468, -0.42668081, -0.09125871,  1.73550053,  1.63990114,
#          2.89154648],
#        [ 1.45814843, -0.28025575,  1.86053334,  2.5660378 ,  1.30378146,
#          2.51996144],
#        [ 1.01160804,  2.22835446,  0.37490566,  1.04682173,  2.445785  ,
#          2.07576197],
#        [-0.43271623,  1.77711938,  0.48826007,  1.14139618,  2.56892937,
#          2.70354   ],
#        [ 0.24682989, -1.19423957,  0.23831124,  0.1610207 ,  2.28544399,
#          3.57130315],
#        [-1.99157036, -0.25413427,  0.81628737,  2.32675753,  1.08736376,
#          1.39132931],
#        [-0.27896533, -0.20487222,  0.84448929,  1.43116767,  3.86540215,
#          0.88033001],
#        [ 0.87278912, -0.16557943, -0.88591557,  0.63668689,  3.2905847 ,
#          5.1440781 ],
#        [ 0.40005353,  1.25972364,  2.32691578,  0.57625848,  1.870576  ,
#          2.86827338],
#        [-0.88582621, -0.84673235,  0.18647731,  2.2812026 ,  3.3282326 ,
#          4.76292626],
#        [-0.65019927, -0.98572736,  1.34830372,  1.96458195,  0.25768023,
#          2.64420063],
#        [ 1.28584298, -0.80579545,  1.20382719, -0.21551229,  0.81134826,
#          2.43932095],
#        [-0.82862699,  0.87686532,  1.23484115,  2.05653914,  2.35805063,
#          1.50455044],
#        [-0.55855481,  2.55871972,  2.08836169,  2.12113808,  1.98929247,
#          2.35588991],
#        [-0.29122748,  0.09410164,  0.51067163,  2.41913341,  0.54735929,
#          2.14975781],
#        [ 1.51197811,  2.23273505,  1.76934725,  3.13603859,  3.63763416,
#          1.59158105],
#        [ 0.1499795 , -1.02440747,  1.80828703,  2.19834244,  2.00960041,
#          1.06039795],
#        [-0.32820232,  1.02654106,  0.27300934,  1.43332798,  2.05611859,
#          0.90234675],
#        [ 2.27649075,  1.17171558,  0.05390244,  2.0268673 ,  1.64028746,
#          3.48753969],
#        [ 0.21285792,  1.99907668,  1.72181682,  2.63189327,  1.37453289,
#          1.55885562]])

# %%
#boxplot
sns.boxplot(data=data)

# %%
#violinplot
sns.violinplot(data=data)
sns.despine(offset=10, trim=True);
#offset: away from the axes 
#trim: if True:  limit spines to the smallest and largest major tick on each non-despined axis.

# %%
#function of sns.despine
sns.set_style("whitegrid")
sns.boxplot(data=data, palette="deep")
sns.despine(left=True)# if True: 删除左边边框

# %%
# 散點圖關聯變量
tips = sns.load_dataset("tips")
sns.set(style="darkgrid")
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
#使用「色調語義」,因為點的顏色獲得意義:
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
# 通過獨立地改變每個點的色調和样式，也可以表示四個變量(x,y,smoker,style)
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);

# %%
fmri = sns.load_dataset("fmri")
#透過replot 畫lineplot
#預設行為是透過繪製平均值和 95% 信心區間圍繞平均值來聚合每個值的多個測量值:
#自信區間是通過自助取樣法（bootstrapping）計算的
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# %%
#信心區間是使用引導計算的,對於較大的數據集,這需要時間。因此,可以禁用它們:
#ci: [int,'sd',None],置信区间的大小，当为‘sd’时绘制数据的标准差
sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);#ci = None

# %%
#另一個不錯的選擇(尤其是對於較大的數據)是通過繪製標準差而不是信心區間來表示每個時間點的分佈分佈:
sns.relplot(x="timepoint", y="signal", kind="line", ci="sd", data=fmri);#ci = standard deviation

# %%
sns.relplot(x="timepoint", y="signal", hue="event", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            kind="line", data=fmri);

# %%
#單變數分佈圖
#默認情況下,這將繪製直方圖並適合內核密度估計值(KDE)。
x = np.random.normal(size=100)
sns.distplot(x);

# %%
# bin: 指的是特徵值(直方條 總個數）, 先取消KDE 避免混淆
sns.distplot(x, bins=20, kde=False, rug=True);#rug:是否顯示資料分佈情況＃

# %% [markdown]
# # HW

# %%
rs = np.random.RandomState(8)
x = rs.normal(2, 1, 75)
y = 2 + 1.5 * x + rs.normal(0, 2, 75)

# %%
#模型殘差 圖型(residplot()): 该方法将在x上回归y，然后绘制残差的散点图。
sns.set_style('whitegrid')#有五種預設seaborn主題：darkgrid，whitegrid，dark，white
sns.residplot(x=x, y=y);

# %%
#繪製單變數分佈:
sns.set_style('dark')
sns.distplot(x,kde=False,bins=10)

# %%
sns.set_style('dark')
sns.distplot(x,kde=False,bins=30)

# %%
sns.set_style('dark')
sns.distplot(y,bins=10)
